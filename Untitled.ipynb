# %%
url = "https://previews.123rf.com/images/ivanmogilevchik/ivanmogilevchik1610/ivanmogilevchik161000030/64153272-%EB%8B%A4%EC%96%91%ED%95%9C-%EA%BD%83%EC%9C%BC%EB%A1%9C-%EC%84%A4%EC%A0%95-%EC%8B%9D%EC%8A%A4-%ED%8F%89%EB%A9%B4%EB%8F%84-%EA%B3%A0%EB%A6%BD-%ED%98%84%EC%8B%A4%EC%A0%81%EC%9D%B8-%EA%BD%83-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EB%B9%88-%EB%B0%B0%EA%B2%BD-%EB%B2%A1%ED%84%B0-%EC%9D%BC%EB%9F%AC%EC%8A%A4%ED%8A%B8-%EB%A0%88%EC%9D%B4-%EC%85%98%EC%97%90-%EA%BD%83%EC%9D%84.jpg"

# %%
import requests

image_binary = requests.get(url).content

with open("flower.jpg", "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image

flower_image = Image.open("flower.jpg")

# %%
from pilkit.processors import Thumbnail

processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(flower_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x1797870>

# %%
thumb_image.save("thumb-300x300.png")

for quality in [100, 80, 60, 40, 20]:
    thumb_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\dev\envs\venv\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     627     try:
# --> 628         rawmode = RAWMODE[im.mode]
#     629     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-b9be6681c7fa> in <module>
#       2
#       3 for quality in [100, 80, 60, 40, 20]:
# ----> 4     thumb_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
#
# c:\dev\envs\venv\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2086
#    2087         try:
# -> 2088             save_handler(self, fp, filename)
#    2089         finally:
#    2090             # do what we can to clean up
#
# ...
